# %% [markdown]
# # Now You Code 4: Movie Goers Zipcode Lookup
#
# The movie company has hired you to help them enhance their data set. They would like to know which **US State** each of the respondents in their movie goers survey comes from, and ask you to produce a list of states and a count of movie goers from that state.
#
# The movie goers dataset `'NYC1-moviegoers.csv'` from NYC1 contains `'zip_code'` but not city and state.
#
# We will load another pandas dataset, **the Zipcode Database** here:
# `'https://raw.githubusercontent.com/mafudge/datasets/master/zipcodes/free-zipcode-database-Primary.csv'` This data set contains Zip codes with primary city, state and approximate location.
#
# Your goal is to figure out how to use the `DataFrame.merge()` method to combine these two data sets on matching zip code values.
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html
#
# After you merge the dataset, then you can complete the task and provide a count of movie goers by state.

# %%
# import pandas
import pandas as pd

# this turns off warning messages
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Part 1: Load the movie goers dataset into a Pandas DataFrame
#
# Write code to load the movie goers dataset (in csv format) into the variable `moviegoers` and then print the first few rows.

# %%
moviegoers = pd.read_csv('NYC1-moviegoers.csv')
moviegoers.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# ### Part 2: Load the zip code database into a Pandas DataFrame
#
# Write code to load the movie goers dataset (in csv format) into the variable `zipcodes` and then print the first few rows.
#
# The database (in csv format) can be found here: `'https://raw.githubusercontent.com/mafudge/datasets/master/zipcodes/free-zipcode-database-Primary.csv'`
#
# **HINT:**  You must include the named argument `dtype={'Zipcode': object}` to the `read_csv()` method to force the `Zipcode` series to be the same type as in the `moviegoers` dataframe.

# %%
zipcodes = pd.read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/zipcodes/free-zipcode-database-Primary.csv', dtype={'Zipcode' : object})

zipcodes
# Out:
#       Zipcode ZipCodeType                City State LocationType    Lat  \
# 0       00705    STANDARD            AIBONITO    PR      PRIMARY  18.14
# 1       00610    STANDARD              ANASCO    PR      PRIMARY  18.28
# 2       00611      PO BOX             ANGELES    PR      PRIMARY  18.28
# 3       00612    STANDARD             ARECIBO    PR      PRIMARY  18.45
# 4       00601    STANDARD            ADJUNTAS    PR      PRIMARY  18.16
# 5       00631      PO BOX            CASTANER    PR      PRIMARY  18.19
# 6       00602    STANDARD              AGUADA    PR      PRIMARY  18.38
# 7       00603    STANDARD           AGUADILLA    PR      PRIMARY  18.43
# 8       00604      PO BOX           AGUADILLA    PR      PRIMARY  18.43
# 9       00605      PO BOX           AGUADILLA    PR      PRIMARY  18.43
# 10      00703    STANDARD        AGUAS BUENAS    PR      PRIMARY  18.25
# 11      00704    STANDARD             AGUIRRE    PR      PRIMARY  17.96
# 12      07675    STANDARD            WESTWOOD    NJ      PRIMARY  40.98
# 13      07677    STANDARD      WOODCLIFF LAKE    NJ      PRIMARY  41.02
# 14      07885    STANDARD             WHARTON    NJ      PRIMARY  40.89
# 15      07981    STANDARD            WHIPPANY    NJ      PRIMARY  40.82
# 16      07999    STANDARD            WHIPPANY    NJ      PRIMARY  40.82
# 17      08888      PO BOX          WHITEHOUSE    NJ      PRIMARY  40.62
# 18      08889    STANDARD  WHITEHOUSE STATION    NJ      PRIMARY  40.60
# 19      07095    STANDARD          WOODBRIDGE    NJ      PRIMARY  40.55
# 20      07481    STANDARD             WYCKOFF    NJ      PRIMARY  40.99
# 21      10451    STANDARD               BRONX    NY      PRIMARY  40.84
# 22      10452    STANDARD               BRONX    NY      PRIMARY  40.84
# 23      10453    STANDARD               BRONX    NY      PRIMARY  40.84
# 24      10454    STANDARD               BRONX    NY      PRIMARY  40.84
# 25      10455    STANDARD               BRONX    NY      PRIMARY  40.84
# 26      10456    STANDARD               BRONX    NY      PRIMARY  40.84
# 27      10457    STANDARD               BRONX    NY      PRIMARY  40.84
# 28      10458    STANDARD               BRONX    NY      PRIMARY  40.84
# 29      10459    STANDARD               BRONX    NY      PRIMARY  40.84
# ...       ...         ...                 ...   ...          ...    ...
# 42492   97372    STANDARD          ROSE LODGE    OR      PRIMARY  45.01
# 42493   97425      PO BOX       CRESCENT LAKE    OR      PRIMARY  43.47
# 42494   97427    STANDARD          CULP CREEK    OR      PRIMARY  43.68
# 42495   97428      PO BOX              CURTIN    OR      PRIMARY  43.74
# 42496   97472    STANDARD       COTTAGE GROVE    OR      PRIMARY  43.79
# 42497   97482    STANDARD            THURSTON    OR      PRIMARY  44.05
# 42498   98054    STANDARD             REDONDO    WA      PRIMARY  47.34
# 42499   98151      UNIQUE             SEATTLE    WA      PRIMARY  47.60
# 42500   98171    STANDARD             SEATTLE    WA      PRIMARY  47.60
# 42501   98184      UNIQUE             SEATTLE    WA      PRIMARY  47.60
# 42502   98442    STANDARD              TACOMA    WA      PRIMARY  47.14
# 42503   98450      UNIQUE              TACOMA    WA      PRIMARY  47.25
# 42504   98455      UNIQUE              TACOMA    WA      PRIMARY  47.25
# 42505   98460      UNIQUE              TACOMA    WA      PRIMARY  47.25
# 42506   98477      UNIQUE              TACOMA    WA      PRIMARY  47.25
# 42507   98492    STANDARD              TACOMA    WA      PRIMARY  47.12
# 42508   98667      UNIQUE           VANCOUVER    WA      PRIMARY  45.63
# 42509   98929    STANDARD              NACHES    WA      PRIMARY  46.74
# 42510   99165    STANDARD             PULLMAN    WA      PRIMARY  46.73
# 42511   99779    STANDARD                 TOK    AK      PRIMARY  63.13
# 42512   09300    MILITARY                 APO    AE      PRIMARY    NaN
# 42513   09303    MILITARY                 APO    AE      PRIMARY    NaN
# 42514   09379    MILITARY                 FPO    AE      PRIMARY    NaN
# 42515   96400    MILITARY                 APO    AP      PRIMARY    NaN
# 42516   96547    MILITARY                 APO    AP      PRIMARY    NaN
# 42517   34009    MILITARY                 APO    AA      PRIMARY    NaN
# 42518   34010    MILITARY                 APO    AA      PRIMARY    NaN
# 42519   34001    MILITARY                 APO    AA      PRIMARY    NaN
# 42520   34071    MILITARY                 APO    AA      PRIMARY    NaN
# 42521   97475      PO BOX         SPRINGFIELD    OR      PRIMARY  44.05
#
#          Long                                 Location  Decommisioned  \
# 0      -66.26                        NA-US-PR-AIBONITO          False
# 1      -67.14                          NA-US-PR-ANASCO          False
# 2      -66.79                         NA-US-PR-ANGELES          False
# 3      -66.73                         NA-US-PR-ARECIBO          False
# 4      -66.72                        NA-US-PR-ADJUNTAS          False
# 5      -66.82                        NA-US-PR-CASTANER          False
# 6      -67.18                          NA-US-PR-AGUADA          False
# 7      -67.15                       NA-US-PR-AGUADILLA          False
# 8      -67.15                       NA-US-PR-AGUADILLA          False
# 9      -67.15                       NA-US-PR-AGUADILLA          False
# 10     -66.10                    NA-US-PR-AGUAS BUENAS          False
# 11     -66.22                         NA-US-PR-AGUIRRE          False
# 12     -74.03                        NA-US-NJ-WESTWOOD          False
# 13     -74.05                  NA-US-NJ-WOODCLIFF LAKE          False
# 14     -74.58                         NA-US-NJ-WHARTON          False
# 15     -74.41                        NA-US-NJ-WHIPPANY          False
# 16     -74.41                        NA-US-NJ-WHIPPANY          False
# 17     -74.76                      NA-US-NJ-WHITEHOUSE          False
# 18     -74.76              NA-US-NJ-WHITEHOUSE STATION          False
# 19     -74.28                      NA-US-NJ-WOODBRIDGE          False
# 20     -74.16                         NA-US-NJ-WYCKOFF          False
# 21     -73.87                           NA-US-NY-BRONX          False
# 22     -73.87                           NA-US-NY-BRONX          False
# 23     -73.87                           NA-US-NY-BRONX          False
# 24     -73.87                           NA-US-NY-BRONX          False
# 25     -73.87                           NA-US-NY-BRONX          False
# 26     -73.87                           NA-US-NY-BRONX          False
# 27     -73.87                           NA-US-NY-BRONX          False
# 28     -73.87                           NA-US-NY-BRONX          False
# 29     -73.87                           NA-US-NY-BRONX          False
# ...       ...                                      ...            ...
# 42492 -123.87                      NA-US-OR-ROSE LODGE           True
# 42493 -121.92                   NA-US-OR-CRESCENT LAKE           True
# 42494 -122.79                      NA-US-OR-CULP CREEK           True
# 42495 -123.18                          NA-US-OR-CURTIN           True
# 42496 -123.06                   NA-US-OR-COTTAGE GROVE           True
# 42497 -122.91                        NA-US-OR-THURSTON           True
# 42498 -122.32                         NA-US-WA-REDONDO           True
# 42499 -122.33                         NA-US-WA-SEATTLE           True
# 42500 -122.33                         NA-US-WA-SEATTLE           True
# 42501 -122.33                         NA-US-WA-SEATTLE           True
# 42502 -122.43                          NA-US-WA-TACOMA           True
# 42503 -122.44                          NA-US-WA-TACOMA           True
# 42504 -122.44                          NA-US-WA-TACOMA           True
# 42505 -122.44                          NA-US-WA-TACOMA           True
# 42506 -122.44                          NA-US-WA-TACOMA           True
# 42507 -122.55                          NA-US-WA-TACOMA           True
# 42508 -122.66                       NA-US-WA-VANCOUVER           True
# 42509 -121.14                          NA-US-WA-NACHES           True
# 42510 -117.17                         NA-US-WA-PULLMAN           True
# 42511 -142.53                             NA-US-AK-TOK           True
# 42512     NaN                         ME-IQ-CAMP BUCCA           True
# 42513     NaN                        ME-BH-MCA BAHRAIN           True
# 42514     NaN       ME-BH-FMC BAH CONTINGENCY - MANAMA           True
# 42515     NaN                 AS-TH-COBRA GOLD BANGKOK           True
# 42516     NaN                            AS-TH-BANGKOK           True
# 42517     NaN                 SA-GY-NEW HORIZON-GUYANA           True
# 42518     NaN  CA-HN-NEW HORIZON  LA CEIBA - COMAYAGUA           True
# 42519     NaN      CA-NI-JTF JUNTOS  PODEMOS BASE CAMP           True
# 42520     NaN         SA-PY-JTF NEW HORIZON-CONCEPCION           True
# 42521 -123.02                     NA-US-OR-SPRINGFIELD          False
#
#        TaxReturnsFiled  EstimatedPopulation    TotalWages
# 0                  NaN                  NaN           NaN
# 1                  NaN                  NaN           NaN
# 2                  NaN                  NaN           NaN
# 3                  NaN                  NaN           NaN
# 4                  NaN                  NaN           NaN
# 5                  NaN                  NaN           NaN
# 6                  NaN                  NaN           NaN
# 7                  NaN                  NaN           NaN
# 8                  NaN                  NaN           NaN
# 9                  NaN                  NaN           NaN
# 10                 NaN                  NaN           NaN
# 11                 NaN                  NaN           NaN
# 12             13245.0              24083.0  1.089095e+09
# 13              2945.0               5471.0  3.254370e+08
# 14              5273.0               8999.0  2.408280e+08
# 15              4585.0               8057.0  2.920968e+08
# 16                 NaN                  NaN           NaN
# 17                 NaN                  NaN           NaN
# 18              4691.0               8570.0  4.013124e+08
# 19             10018.0              17272.0  5.283150e+08
# 20              8079.0              15208.0  8.962738e+08
# 21             19434.0              31477.0  4.714469e+08
# 22             33517.0              56277.0  7.235085e+08
# 23             34152.0              57691.0  6.996118e+08
# 24             13139.0              22387.0  2.731196e+08
# 25             14914.0              25139.0  3.252742e+08
# 26             34793.0              58750.0  7.329075e+08
# 27             29023.0              48779.0  6.142731e+08
# 28             29920.0              50085.0  6.934473e+08
# 29             17977.0              30434.0  4.140217e+08
# ...                ...                  ...           ...
# 42492              NaN                  NaN           NaN
# 42493              NaN                  NaN           NaN
# 42494              NaN                  NaN           NaN
# 42495              NaN                  NaN           NaN
# 42496              NaN                  NaN           NaN
# 42497              NaN                  NaN           NaN
# 42498              NaN                  NaN           NaN
# 42499              NaN                  NaN           NaN
# 42500              NaN                  NaN           NaN
# 42501              NaN                  NaN           NaN
# 42502              NaN                  NaN           NaN
# 42503              NaN                  NaN           NaN
# 42504              NaN                  NaN           NaN
# 42505              NaN                  NaN           NaN
# 42506              NaN                  NaN           NaN
# 42507              NaN                  NaN           NaN
# 42508              NaN                  NaN           NaN
# 42509              NaN                  NaN           NaN
# 42510              NaN                  NaN           NaN
# 42511              NaN                  NaN           NaN
# 42512              NaN                  NaN           NaN
# 42513              NaN                  NaN           NaN
# 42514              NaN                  NaN           NaN
# 42515              NaN                  NaN           NaN
# 42516              NaN                  NaN           NaN
# 42517              NaN                  NaN           NaN
# 42518              NaN                  NaN           NaN
# 42519              NaN                  NaN           NaN
# 42520              NaN                  NaN           NaN
# 42521              NaN                  NaN           NaN
#
# [42522 rows x 12 columns]

# %% [markdown]
# ### Part 3: Merge both data sets into a single combined DataFrame
#
# Next we must merge the `moviegoers` DataFrame with the `zipcodes` DataFrame. To do this you must specify which zip code column from `moviegoers` matches the zip cod column from `zipcodes` (as you can see they have different names).
#
# ```
# Help on method merge in module pandas.core.frame:
#
# merge(right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False) method of pandas.core.frame.DataFrame instance
#     Merge DataFrame objects by performing a database-style join operation by
#     columns or indexes.
# ```
#
# The type of merge we will do is an `inner`, because we only want rows when the zip codes match. This is called an *intersection*.
#
# To complete a merge we must specify the column names from the left and right DataFrames.  Most of the code has been written for you. Your task is to complete the columns for the merge, replacing `????` with the appropriate column names.

# %%
intersection = pd.merge(moviegoers, zipcodes, left_on=['zip_code'], right_on=['Zipcode'], how = 'inner')
intersection
# Out:
#      user_id  age gender     occupation zip_code Zipcode ZipCodeType  \
# 0          1   24      M     technician    85711   85711    STANDARD
# 1        415   39      M       educator    85711   85711    STANDARD
# 2          2   53      F          other    94043   94043    STANDARD
# 3         29   41      M     programmer    94043   94043    STANDARD
# 4        105   24      M       engineer    94043   94043    STANDARD
# 5          3   23      M         writer    32067   32067      PO BOX
# 6          4   24      M     technician    43537   43537    STANDARD
# 7          5   33      F          other    15213   15213    STANDARD
# 8          6   42      M      executive    98101   98101    STANDARD
# 9          7   57      M  administrator    91344   91344    STANDARD
# 10       331   33      M  entertainment    91344   91344    STANDARD
# 11        10   53      M         lawyer    90703   90703    STANDARD
# 12        11   39      F          other    30329   30329    STANDARD
# 13        13   47      M       educator    29206   29206    STANDARD
# 14        14   45      M      scientist    55106   55106    STANDARD
# 15       300   26      F     programmer    55106   55106    STANDARD
# 16       609   13      F        student    55106   55106    STANDARD
# 17        15   49      F       educator    97301   97301    STANDARD
# 18       350   32      M        student    97301   97301    STANDARD
# 19       890   32      M        student    97301   97301    STANDARD
# 20        16   21      M  entertainment    10309   10309    STANDARD
# 21        18   35      F          other    37212   37212    STANDARD
# 22        20   42      F      homemaker    95660   95660    STANDARD
# 23        21   26      M         writer    30068   30068    STANDARD
# 24        22   25      M         writer    40206   40206    STANDARD
# 25        23   30      F         artist    48197   48197    STANDARD
# 26       354   29      F      librarian    48197   48197    STANDARD
# 27        24   21      F         artist    94533   94533    STANDARD
# 28       422   26      M  entertainment    94533   94533    STANDARD
# 29        25   39      M       engineer    55107   55107    STANDARD
# ..       ...  ...    ...            ...      ...     ...         ...
# 791      896   28      M         writer    91505   91505    STANDARD
# 792      897   30      M          other    33484   33484    STANDARD
# 793      900   60      M        retired    18505   18505    STANDARD
# 794      902   45      F         artist    97203   97203    STANDARD
# 795      903   28      M       educator    20850   20850    STANDARD
# 796      904   17      F        student    61073   61073    STANDARD
# 797      905   27      M          other    30350   30350    STANDARD
# 798      906   45      M      librarian    70124   70124    STANDARD
# 799      908   44      F      librarian    68504   68504    STANDARD
# 800      909   50      F       educator    53171   53171      PO BOX
# 801      910   28      M     healthcare    29301   29301    STANDARD
# 802      911   37      F         writer    53210   53210    STANDARD
# 803      913   27      M        student    76201   76201    STANDARD
# 804      915   50      M  entertainment    60614   60614    STANDARD
# 805      917   22      F        student    20006   20006    STANDARD
# 806      918   40      M      scientist    70116   70116    STANDARD
# 807      920   30      F         artist    90008   90008    STANDARD
# 808      921   20      F        student    98801   98801    STANDARD
# 809      924   29      M          other    11753   11753    STANDARD
# 810      925   18      F       salesman    49036   49036    STANDARD
# 811      927   23      M     programmer    55428   55428    STANDARD
# 812      931   60      M       educator    33556   33556    STANDARD
# 813      933   28      M        student    48105   48105    STANDARD
# 814      935   42      M         doctor    66221   66221    STANDARD
# 815      936   24      M          other    32789   32789    STANDARD
# 816      938   38      F     technician    55038   55038    STANDARD
# 817      939   26      F        student    33319   33319    STANDARD
# 818      941   20      M        student    97229   97229    STANDARD
# 819      942   48      F      librarian    78209   78209    STANDARD
# 820      943   22      M        student    77841   77841      PO BOX
#
#                 City State LocationType    Lat    Long  \
# 0             TUCSON    AZ      PRIMARY  32.21 -110.88
# 1             TUCSON    AZ      PRIMARY  32.21 -110.88
# 2      MOUNTAIN VIEW    CA      PRIMARY  37.41 -122.05
# 3      MOUNTAIN VIEW    CA      PRIMARY  37.41 -122.05
# 4      MOUNTAIN VIEW    CA      PRIMARY  37.41 -122.05
# 5        ORANGE PARK    FL      PRIMARY  30.16  -81.70
# 6             MAUMEE    OH      PRIMARY  41.57  -83.65
# 7         PITTSBURGH    PA      PRIMARY  40.43  -79.97
# 8            SEATTLE    WA      PRIMARY  47.61 -122.33
# 9      GRANADA HILLS    CA      PRIMARY  34.29 -118.50
# 10     GRANADA HILLS    CA      PRIMARY  34.29 -118.50
# 11          CERRITOS    CA      PRIMARY  33.86 -118.05
# 12           ATLANTA    GA      PRIMARY  33.82  -84.32
# 13          COLUMBIA    SC      PRIMARY  34.00  -81.03
# 14        SAINT PAUL    MN      PRIMARY  44.94  -93.10
# 15        SAINT PAUL    MN      PRIMARY  44.94  -93.10
# 16        SAINT PAUL    MN      PRIMARY  44.94  -93.10
# 17             SALEM    OR      PRIMARY  44.90 -122.92
# 18             SALEM    OR      PRIMARY  44.90 -122.92
# 19             SALEM    OR      PRIMARY  44.90 -122.92
# 20     STATEN ISLAND    NY      PRIMARY  40.58  -74.14
# 21         NASHVILLE    TN      PRIMARY  36.17  -86.78
# 22   NORTH HIGHLANDS    CA      PRIMARY  38.66 -121.37
# 23          MARIETTA    GA      PRIMARY  33.95  -84.54
# 24        LOUISVILLE    KY      PRIMARY  38.22  -85.74
# 25         YPSILANTI    MI      PRIMARY  42.24  -83.62
# 26         YPSILANTI    MI      PRIMARY  42.24  -83.62
# 27         FAIRFIELD    CA      PRIMARY  38.28 -122.00
# 28         FAIRFIELD    CA      PRIMARY  38.28 -122.00
# 29        SAINT PAUL    MN      PRIMARY  44.94  -93.10
# ..               ...   ...          ...    ...     ...
# 791          BURBANK    CA      PRIMARY  34.17 -118.34
# 792     DELRAY BEACH    FL      PRIMARY  26.45  -80.08
# 793         SCRANTON    PA      PRIMARY  41.40  -75.66
# 794         PORTLAND    OR      PRIMARY  45.61 -122.74
# 795        ROCKVILLE    MD      PRIMARY  39.08  -77.15
# 796           ROSCOE    IL      PRIMARY  42.41  -89.00
# 797          ATLANTA    GA      PRIMARY  33.97  -84.32
# 798      NEW ORLEANS    LA      PRIMARY  30.06  -89.93
# 799          LINCOLN    NE      PRIMARY  40.81  -96.68
# 800           SOMERS    WI      PRIMARY  42.58  -87.89
# 801      SPARTANBURG    SC      PRIMARY  34.94  -81.92
# 802        MILWAUKEE    WI      PRIMARY  43.06  -87.96
# 803           DENTON    TX      PRIMARY  33.21  -97.13
# 804          CHICAGO    IL      PRIMARY  41.83  -87.68
# 805       WASHINGTON    DC      PRIMARY  38.89  -77.03
# 806      NEW ORLEANS    LA      PRIMARY  30.06  -89.93
# 807      LOS ANGELES    CA      PRIMARY  34.00 -118.34
# 808        WENATCHEE    WA      PRIMARY  47.37 -120.35
# 809          JERICHO    NY      PRIMARY  40.78  -73.54
# 810        COLDWATER    MI      PRIMARY  41.94  -85.00
# 811      MINNEAPOLIS    MN      PRIMARY  44.96  -93.26
# 812           ODESSA    FL      PRIMARY  28.20  -82.59
# 813        ANN ARBOR    MI      PRIMARY  42.27  -83.73
# 814    OVERLAND PARK    KS      PRIMARY  38.90  -94.68
# 815      WINTER PARK    FL      PRIMARY  28.59  -81.34
# 816             HUGO    MN      PRIMARY  45.15  -92.96
# 817  FORT LAUDERDALE    FL      PRIMARY  26.14  -80.13
# 818         PORTLAND    OR      PRIMARY  45.55 -122.81
# 819      SAN ANTONIO    TX      PRIMARY  29.45  -98.50
# 820  COLLEGE STATION    TX      PRIMARY  30.60  -96.31
#
#                      Location  Decommisioned  TaxReturnsFiled  \
# 0             NA-US-AZ-TUCSON          False          17554.0
# 1             NA-US-AZ-TUCSON          False          17554.0
# 2      NA-US-CA-MOUNTAIN VIEW          False          14062.0
# 3      NA-US-CA-MOUNTAIN VIEW          False          14062.0
# 4      NA-US-CA-MOUNTAIN VIEW          False          14062.0
# 5        NA-US-FL-ORANGE PARK          False            545.0
# 6             NA-US-OH-MAUMEE          False          14432.0
# 7         NA-US-PA-PITTSBURGH          False           6666.0
# 8            NA-US-WA-SEATTLE          False           6245.0
# 9      NA-US-CA-GRANADA HILLS          False          23384.0
# 10     NA-US-CA-GRANADA HILLS          False          23384.0
# 11          NA-US-CA-CERRITOS          False          24073.0
# 12           NA-US-GA-ATLANTA          False          11542.0
# 13          NA-US-SC-COLUMBIA          False           8882.0
# 14        NA-US-MN-SAINT PAUL          False          21868.0
# 15        NA-US-MN-SAINT PAUL          False          21868.0
# 16        NA-US-MN-SAINT PAUL          False          21868.0
# 17             NA-US-OR-SALEM          False          19211.0
# 18             NA-US-OR-SALEM          False          19211.0
# 19             NA-US-OR-SALEM          False          19211.0
# 20     NA-US-NY-STATEN ISLAND          False          13982.0
# 21         NA-US-TN-NASHVILLE          False           6761.0
# 22   NA-US-CA-NORTH HIGHLANDS          False          12192.0
# 23          NA-US-GA-MARIETTA          False          15207.0
# 24        NA-US-KY-LOUISVILLE          False           9966.0
# 25         NA-US-MI-YPSILANTI          False          26129.0
# 26         NA-US-MI-YPSILANTI          False          26129.0
# 27         NA-US-CA-FAIRFIELD          False          28284.0
# 28         NA-US-CA-FAIRFIELD          False          28284.0
# 29        NA-US-MN-SAINT PAUL          False           6009.0
# ..                        ...            ...              ...
# 791          NA-US-CA-BURBANK          False          16193.0
# 792     NA-US-FL-DELRAY BEACH          False          11799.0
# 793         NA-US-PA-SCRANTON          False           9565.0
# 794         NA-US-OR-PORTLAND          False          12253.0
# 795        NA-US-MD-ROCKVILLE          False          21446.0
# 796           NA-US-IL-ROSCOE          False           9583.0
# 797          NA-US-GA-ATLANTA          False          15905.0
# 798      NA-US-LA-NEW ORLEANS          False           6943.0
# 799          NA-US-NE-LINCOLN          False           7516.0
# 800           NA-US-WI-SOMERS          False              NaN
# 801      NA-US-SC-SPARTANBURG          False          13226.0
# 802        NA-US-WI-MILWAUKEE          False          11228.0
# 803           NA-US-TX-DENTON          False           8336.0
# 804          NA-US-IL-CHICAGO          False          34622.0
# 805       NA-US-DC-WASHINGTON          False            826.0
# 806      NA-US-LA-NEW ORLEANS          False           4612.0
# 807      NA-US-CA-LOS ANGELES          False          13333.0
# 808        NA-US-WA-WENATCHEE          False          16933.0
# 809          NA-US-NY-JERICHO          False           6522.0
# 810        NA-US-MI-COLDWATER          False          10391.0
# 811      NA-US-MN-MINNEAPOLIS          False          14155.0
# 812           NA-US-FL-ODESSA          False           9885.0
# 813        NA-US-MI-ANN ARBOR          False          15149.0
# 814    NA-US-KS-OVERLAND PARK          False           6164.0
# 815      NA-US-FL-WINTER PARK          False          11484.0
# 816             NA-US-MN-HUGO          False           9470.0
# 817  NA-US-FL-FORT LAUDERDALE          False          22648.0
# 818         NA-US-OR-PORTLAND          False          24907.0
# 819      NA-US-TX-SAN ANTONIO          False          18516.0
# 820  NA-US-TX-COLLEGE STATION          False            291.0
#
#      EstimatedPopulation    TotalWages
# 0                29028.0  5.068503e+08
# 1                29028.0  5.068503e+08
# 2                22824.0  1.083207e+09
# 3                22824.0  1.083207e+09
# 4                22824.0  1.083207e+09
# 5                  853.0  1.621657e+07
# 6                24370.0  6.686273e+08
# 7                 8837.0  2.003182e+08
# 8                 7771.0  3.217270e+08
# 9                41602.0  1.102040e+09
# 10               41602.0  1.102040e+09
# 11               44208.0  1.238371e+09
# 12               18677.0  4.480111e+08
# 13               15489.0  4.179884e+08
# 14               36448.0  6.356612e+08
# 15               36448.0  6.356612e+08
# 16               36448.0  6.356612e+08
# 17               33441.0  4.967644e+08
# 18               33441.0  4.967644e+08
# 19               33441.0  4.967644e+08
# 20               25371.0  8.058242e+08
# 21                9599.0  3.848726e+08
# 22               21675.0  3.103610e+08
# 23               28538.0  1.156659e+09
# 24               14856.0  3.804385e+08
# 25               43735.0  1.027227e+09
# 26               43735.0  1.027227e+09
# 27               51145.0  1.053583e+09
# 28               51145.0  1.053583e+09
# 29               10102.0  1.869889e+08
# ..                   ...           ...
# 791              25892.0  8.328821e+08
# 792              17552.0  2.433182e+08
# 793              15444.0  2.572213e+08
# 794              19921.0  4.069400e+08
# 795              37165.0  1.500086e+09
# 796              18117.0  4.935098e+08
# 797              25506.0  9.980255e+08
# 798              11455.0  3.993478e+08
# 799              11396.0  2.049966e+08
# 800                  NaN           NaN
# 801              23385.0  4.516295e+08
# 802              18640.0  2.886779e+08
# 803              11718.0  1.857307e+08
# 804              47140.0           NaN
# 805               1044.0  4.116180e+07
# 806               6580.0  1.294656e+08
# 807              21174.0  4.266898e+08
# 808              30299.0  5.916501e+08
# 809              12072.0  6.395171e+08
# 810              18378.0  3.037791e+08
# 811              23451.0  4.915491e+08
# 812              19062.0  6.654544e+08
# 813              25072.0  9.017334e+08
# 814              12706.0  6.561749e+08
# 815              18789.0  8.602018e+08
# 816              17873.0  5.519424e+08
# 817              35782.0  6.018403e+08
# 818              47620.0  1.903461e+09
# 819              30337.0  1.117996e+09
# 820                400.0  8.870991e+06
#
# [821 rows x 17 columns]

# %% [markdown]
# ### Part 4: Merge both data sets into a single combined DataFrame
#
# Finally, produce the desired output a list of states and counts of movie goers from the survey in each state.
#
# Here's the top 5 for reference:
#
# ```
# CA    116
# MN     78
# NY     60
# TX     51
# IL     50
# ```

# %%
movie_goers = intersection[ ['user_id', 'State']]
movie_goers['State'].value_counts().head(5)
# Out:
# CA    116
# MN     78
# NY     60
# TX     51
# IL     50
# Name: State, dtype: int64

# %% [markdown]
# ## Reminder of Evaluation Criteria
#
# 1. What the problem attempted (analysis, code, and answered questions) ?
# 2. What the problem analysis thought out? (does the program match the plan?)
# 3. Does the code execute without syntax error?
# 4. Does the code solve the intended problem?
# 5. Is the code well written? (easy to understand, modular, and self-documenting, handles errors)
